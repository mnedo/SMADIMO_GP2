# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cities = pd.read_excel('Датасет городов.xlsx').drop('Unnamed: 0', axis=1)
cities
# Out:
#           Город                Регион Федеральный округ  Население  \
# 0         Абаза               Хакасия         Сибирский      12272
# 1        Абакан               Хакасия         Сибирский     184284
# 2      Абдулино  Оренбургская область       Приволжский      17274
# 3        Абинск    Краснодарский край             Южный      38440
# 4       Агидель          Башкортостан       Приволжский      14219
# ...         ...                   ...               ...        ...
# 1120  Ярославль   Ярославская область       Центральный     563717
# 1121     Ярцево    Смоленская область       Центральный      40330
# 1122  Ясногорск      Тульская область       Центральный      15269
# 1123      Ясный  Оренбургская область       Приволжский      15471
# 1124     Яхрома    Московская область       Центральный      13618
#
#       Наличие аэропорта
# 0                 False
# 1                  True
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 1120               True
# 1121              False
# 1122              False
# 1123              False
# 1124              False
#
# [1125 rows x 5 columns]

# %% [markdown]
# Будем придерживаться следующей стратегии: <br>
# Мы хотим диверсифицировать наш анализ по округам, т.е. в каждом округе посмотрим регионы и города - выберем топ в каждой группе (округе). Эти топы и возьмем для дальнейшего анализа.

# %% [markdown]
# Проверим, во всех ли федеральных округах есть аэропорт

# %%
cities.groupby('Федеральный округ')['Наличие аэропорта'].sum().sort_values()
# Out:
# Федеральный округ
# Северо-Кавказский     7
# Северо-Западный       8
# Южный                 8
# Уральский             8
# Центральный           9
# Дальневосточный      10
# Сибирский            12
# Приволжский          13
# Name: Наличие аэропорта, dtype: int64

# %% [markdown]
# Далее выкенем те регионы, в которых нет ни одного аэропорта, т.к. это серьезно влияет на транспортную доступность + далее мы будем рассматривать именно авиаперелеты

# %%
a = cities.groupby('Регион')['Наличие аэропорта'].sum().sort_values()
cities1 = cities[~cities['Регион'].isin(a[a == 0].index)]
print(f'до удаления {len(cities)} и после: {len(cities1)}')
# Out:
# до удаления 1125 и после: 878

# %%
group = cities1.groupby('Федеральный округ')[['Регион', 'Население']].agg({'Регион': 'count', 'Население':'sum'})
group
# Out:
#                    Регион  Население
# Федеральный округ
# Дальневосточный        80    4908776
# Приволжский           167   17439797
# Северо-Западный       104    5183822
# Северо-Кавказский      59    4877311
# Сибирский             109   11268723
# Уральский              98    8725039
# Центральный           168   11833321
# Южный                  93    9391463

# %% [markdown]
# Посмотрим на плотность население по округам

# %%
labels = group.index
sizes = group['Население'] / group['Население'].sum()

plt.figure(figsize=(16, 9))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=['#ace8fc','#c7f0ff','#8fd3f4','#d6c1ff','#cbb2fe','#ffd6e7','#ffbfd8','#e6f7ff'])
plt.show()

# %% [markdown]
# Далее мы хотим сохранить все округа, но выкинуть оттуда города с наименьшим населением - там меньше всего экономической активности. Плотность в разных округах тоже разная, поэтому граница отбрасывания тоже должна зависеть напрямую от статистики населения округа

# %%
districts = cities['Федеральный округ'].unique()
sl = {}
for elem in districts:
  sl[elem] = cities1[cities1['Федеральный округ'] == elem]['Население'].quantile(0.9)
  print(f'Статистика округа {elem}: 90% данных меньше {cities1[cities1['Федеральный округ'] == elem]['Население'].quantile(0.9)}')
# Out:
# Статистика округа Сибирский: 90% данных меньше 180225.6
# Статистика округа Приволжский: 90% данных меньше 196581.20000000016
# Статистика округа Южный: 90% данных меньше 212359.9999999999
# Статистика округа Северо-Кавказский: 90% данных меньше 146538.80000000005
# Статистика округа Уральский: 90% данных меньше 144620.69999999998
# Статистика округа Дальневосточный: 90% данных меньше 179120.30000000002
# Статистика округа Центральный: 90% данных меньше 162865.20000000024
# Статистика округа Северо-Западный: 90% данных меньше 82407.70000000003

# %% [markdown]
# Продолжим фильтрацию городов - уберем самые маленькие (нижние 90%), но, если в этом городе есть аэропорт, то мы его осатвим, чтобы не ухудшать транспортную доступность во всем регионе

# %%
cities3 = cities1[cities1.apply(lambda x: x['Население'] >= sl[x['Федеральный округ']] or x['Наличие аэропорта'] == True, axis=1)]
len(cities3)
# Out:
# 104

# %%
len(cities3['Регион'].unique())
# Out:
# 63

# %% [markdown]
# Осталось 63 региона и 104 города - далее именно их мы и будем рассматривать

# %%
cities3.to_excel('Итоговый список городов.xlsx', index=False)

# %% [markdown]
# Для следующего этапа нам понадобятся английские названия городов - возьмем его уже из готового json файла с гитхаба https://github.com/arbaev/russia-cities/blob/master/russia-cities.json

# %%
df = pd.read_json('russia-cities.json')
cities4 = cities3.merge(df[['name', 'name_en']], left_on='Город', right_on='name', how='left')
cities4
# Out:
#               Город                 Регион Федеральный округ  Население  \
# 0            Абакан                Хакасия         Сибирский     184284
# 1           Анадырь           Чукотский АО   Дальневосточный      13224
# 2             Анапа     Краснодарский край             Южный      84804
# 3           Ангарск      Иркутская область         Сибирский     216973
# 4       Архангельск  Архангельская область   Северо-Западный     294914
# ..              ...                    ...               ...        ...
# 100          Элиста               Калмыкия             Южный     104082
# 101         Энгельс    Саратовская область       Приволжский     222115
# 102  Южно-Сахалинск    Сахалинская область   Дальневосточный     181976
# 103          Якутск                 Якутия   Дальневосточный     372801
# 104       Ярославль    Ярославская область       Центральный     563717
#
#      Наличие аэропорта            name            name_en
# 0                 True          Абакан             Abakan
# 1                 True         Анадырь             Anadyr
# 2                 True           Анапа              Anapa
# 3                False         Ангарск            Angarsk
# 4                 True     Архангельск        Arkhangelsk
# ..                 ...             ...                ...
# 100               True          Элиста             Elista
# 101              False         Энгельс             Engels
# 102               True  Южно-Сахалинск  Yuzhno-Sakhalinsk
# 103               True          Якутск            Yakutsk
# 104               True       Ярославль          Yaroslavl
#
# [105 rows x 7 columns]

# %%
df[df['name'] == 'Благовещенск']
# Out:
#              name      name_alt                          label   type  \
# 27   Благовещенск  Благовещенск  blagoveshchensk_bashkortostan  Город
# 262  Благовещенск  Благовещенск                blagoveshchensk  Город
#
#     typeShort contentType             id        okato        oktmo  \
# 27          г        city   201500100000  80417000000  80615101001
# 262         г        city  2800000100000  10401000000  10701000001
#
#                                      guid  ...  isCapital     zip  population  \
# 27   da7ef573-cdbe-458e-a790-b29ad3a3d140  ...      False  453430       35481
# 262  8f41253d-6e3b-48a9-842a-25ba894bd093  ...       True  675014      241437
#
#      yearFounded yearCityStatus          name_en  \
# 27          1756           1941  Blagoveshchensk
# 262         1856           1858  Blagoveshchensk
#
#                                               namecase  \
# 27   {'nominative': 'Благовещенск', 'genitive': 'Бл...
# 262  {'nominative': 'Благовещенск', 'genitive': 'Бл...
#
#                                      coords  \
# 27   {'lat': 55.0499867, 'lon': 55.9553186}
# 262   {'lat': 50.290659, 'lon': 127.527198}
#
#                                               timezone  \
# 27   {'tzid': 'Asia/Yekaterinburg', 'abbreviation':...
# 262  {'tzid': 'Asia/Yakutsk', 'abbreviation': 'YAKT...
#
#                                                 region
# 27   {'name': 'Башкортостан', 'label': 'bashkortost...
# 262  {'name': 'Амурская', 'label': 'amurskaya', 'ty...
#
# [2 rows x 21 columns]

# %%
cities4[cities4['name_en'].isna() == True]
# Out:
#           Город Регион Федеральный округ  Население  Наличие аэропорта name  \
# 76  Симферополь   Крым             Южный     335009               True  NaN
#
#    name_en
# 76     NaN

# %%
cities4[cities4['Город'] == 'Симферополь']
# Out:
#           Город Регион Федеральный округ  Население  Наличие аэропорта name  \
# 76  Симферополь   Крым             Южный     335009               True  NaN
#
#    name_en
# 76     NaN

# %%
cities4.loc[76,'name_en'] = 'Simferopol'

# %%
cities4[cities4['Город'] == 'Симферополь']
# Out:
#           Город Регион Федеральный округ  Население  Наличие аэропорта name  \
# 76  Симферополь   Крым             Южный     335009               True  NaN
#
#        name_en
# 76  Simferopol

# %%
cities4[cities4['Город'] == 'Благовещенск']
# Out:
#            Город            Регион Федеральный округ  Население  \
# 9   Благовещенск  Амурская область   Дальневосточный     239932
# 10  Благовещенск  Амурская область   Дальневосточный     239932
#
#     Наличие аэропорта          name          name_en
# 9                True  Благовещенск  Blagoveshchensk
# 10               True  Благовещенск  Blagoveshchensk

# %%
cities4 = cities4.drop(10, axis=0)

# %%
len(cities4)
# Out:
# 104

# %%
cities4['name_en'] = cities4['name_en'].apply(lambda x: x.lower())

# %%
cities4
# Out:
#               Город                 Регион Федеральный округ  Население  \
# 0            Абакан                Хакасия         Сибирский     184284
# 1           Анадырь           Чукотский АО   Дальневосточный      13224
# 2             Анапа     Краснодарский край             Южный      84804
# 3           Ангарск      Иркутская область         Сибирский     216973
# 4       Архангельск  Архангельская область   Северо-Западный     294914
# ..              ...                    ...               ...        ...
# 100          Элиста               Калмыкия             Южный     104082
# 101         Энгельс    Саратовская область       Приволжский     222115
# 102  Южно-Сахалинск    Сахалинская область   Дальневосточный     181976
# 103          Якутск                 Якутия   Дальневосточный     372801
# 104       Ярославль    Ярославская область       Центральный     563717
#
#      Наличие аэропорта            name            name_en
# 0                 True          Абакан             abakan
# 1                 True         Анадырь             anadyr
# 2                 True           Анапа              anapa
# 3                False         Ангарск            angarsk
# 4                 True     Архангельск        arkhangelsk
# ..                 ...             ...                ...
# 100               True          Элиста             elista
# 101              False         Энгельс             engels
# 102               True  Южно-Сахалинск  yuzhno-sakhalinsk
# 103               True          Якутск            yakutsk
# 104               True       Ярославль          yaroslavl
#
# [105 rows x 7 columns]

# %%
cities4.to_excel('Итоговый список городов с en.xlsx')
